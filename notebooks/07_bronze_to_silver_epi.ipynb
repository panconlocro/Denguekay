# %% [markdown]
# # 07 — Bronze → Silver: epidemiológico
#
# Cuenta casos por distrito/año/semana y deduplica. Salida: `data/silver/epi_piura_semanal.csv`.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))

# %%
from src.utils.paths import BRONZE_EPI, SILVER
from src.processing.epi_casos import cargar_crudo, construir_casos_semanales, deduplicar_casos

df_epi_raw = cargar_crudo(BRONZE_EPI / "PiuraDengue.xlsx")
df_epi_raw.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1029421 entries, 0 to 1029420
# Data columns (total 14 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   departamento  1029421 non-null  str
#  1   provincia     1029421 non-null  str
#  2   distrito      1029421 non-null  str
#  3   localidad     906823 non-null   str
#  4   enfermedad    1029421 non-null  str
#  5   ano           1029421 non-null  int64
#  6   semana        1029421 non-null  int64
#  7   diagnostic    1029421 non-null  str
#  8   diresa        1029398 non-null  float64
#  9   ubigeo        1029421 non-null  int64
#  10  localcod      880780 non-null   str
#  11  edad          1029421 non-null  int64
#  12  tipo_edad     1029421 non-null  str
#  13  sexo          1029421 non-null  str
# dtypes: float64(1), int64(4), str(9)
# memory usage: 183.3 MB

# %%
df_casos = construir_casos_semanales(df_epi_raw)
df_casos = deduplicar_casos(df_casos)
df_casos.info()
# Out:
# 0 filas con ubigeo-año-semana repetido
# <class 'pandas.DataFrame'>
# RangeIndex: 81196 entries, 0 to 81195
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ubigeo        81196 non-null  int64
#  1   anio          81196 non-null  int64
#  2   semana        81196 non-null  int64
#  3   casos_Dengue  81196 non-null  int64
# dtypes: int64(4)
# memory usage: 2.5 MB

# %%
SILVER.mkdir(parents=True, exist_ok=True)
df_casos.to_csv(SILVER / "epi_piura_semanal.csv", index=False)
