# %% [markdown]
# # 05 — Bronze → Silver: sociodemográfico
#
# Limpia el Excel crudo (duplicados, nombres) e interpola a serie anual 2017-2025 por distrito. Salida: `data/silver/socio_anual.csv`.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))

# %%
from src.utils.paths import BRONZE_SOCIO, SILVER
from src.processing.socio_interpolacion import cargar_crudo, limpiar_duplicados, construir_socio_anual

df_pob = cargar_crudo(BRONZE_SOCIO / "data_socio_2017_2025.xlsx")
df_pob.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 65 entries, 0 to 64
# Data columns (total 63 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   ubigeo                                      65 non-null     int64
#  1   departamento                                65 non-null     str
#  2   provincia                                   65 non-null     str
#  3   distrito                                    65 non-null     str
#  4   pob_proyectada_2018                         65 non-null     int64
#  5   pob_proyectada_2019                         65 non-null     int64
#  6   pob_proyectada_2020                         65 non-null     int64
#  7   pob_proyectada_2021                         65 non-null     int64
#  8   pob_proyectada_2022                         65 non-null     int64
#  9   pob_proyectada_2023                         65 non-null     int64
# ...

# %%
df_pob = limpiar_duplicados(df_pob)
df_pob["distrito"].nunique()
# Out:
# 65

# %%
socio_anual = construir_socio_anual(df_pob)
socio_anual.info()
# Out:
# Variables con un solo año disponible (se descartan, no se interpolan):
#   - fraccion_menores_5 (solo 2017)
#   - fraccion_65_mas (solo 2017)
#   - fraccion_agua_red_no_diaria (solo 2017)
#   - fraccion_hogares_internet (solo 2017)
#   - fraccion_60_mas (solo 2025)
#   - fraccion_hogares_internet_fijo (solo 2025)
#   - fraccion_hogares_internet_movil (solo 2025)
#   - fraccion_asistencia_escolar_3_24 (solo 2025)
#   - fraccion_hogares_basura_quemada (solo 2025)
#   - fraccion_hogares_recolector_municipal (solo 2025)
#   - fraccion_hogares_propios_sin_titulo (solo 2025)
#   - fraccion_hogares_motocicleta (solo 2025)
#   - fraccion_techo_calamina (solo 2025)
#   - fraccion_viviendas_desocupadas (solo 2025)
#   - fraccion_viviendas_improvisadas (solo 2025)
#   - fraccion_mujeres_15_49_sin_hijos (solo 2025)
#   - fraccion_mujeres_12_mas_sin_hijos (solo 2025)
# (585, 22)
# <class 'pandas.DataFrame'>
# RangeIndex: 585 entries, 0 to 584
# Data columns (total 22 columns):
# ...

# %%
SILVER.mkdir(parents=True, exist_ok=True)
socio_anual.to_csv(SILVER / "socio_anual.csv", index=False)
