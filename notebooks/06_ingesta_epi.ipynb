# %% [markdown]
# # 06 — Ingesta epidemiológica (gdown)
#
# Descarga el Excel crudo de casos de dengue desde Google Drive con `gdown`.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))

# %%
import yaml
from src.ingestion.descargar_drive import descargar_epi

cfg = yaml.safe_load(open(Path.cwd().parent / "config" / "config.yaml"))
file_id = cfg["drive"]["epi_file_id"]

path_excel = descargar_epi(file_id)
print(f"Descargado en: {path_excel}")
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1vSPn8SqR4ioz-uDj7HKmem6mgWexin8V
# To: C:\Users\Rosa\RufoEsEternoElRegreso\Denguekay\data\bronze\epi\PiuraDengue.xlsx
# 100%|██████████| 72.8M/72.8M [00:01<00:00, 55.1MB/s]
# Descargado en: C:\Users\Rosa\RufoEsEternoElRegreso\Denguekay\data\bronze\epi\PiuraDengue.xlsx
