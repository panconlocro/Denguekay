# %% [markdown]
# # 04 — Ingesta sociodemográfica (gdown)
#
# Descarga el Excel crudo desde Google Drive con `gdown` (ya no `drive.mount`). El `file_id` sale de `config/config.yaml`.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))

# %%
import yaml
from src.ingestion.descargar_drive import descargar_socio

cfg = yaml.safe_load(open(Path.cwd().parent / "config" / "config.yaml"))
file_id = cfg["drive"]["socio_file_id"]

path_excel = descargar_socio(file_id)
print(f"Descargado en: {path_excel}")
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1x4NoX2vJEs_g3SQyZkfFFwvxTbXO4OBn
# To: C:\Users\Rosa\RufoEsEternoElRegreso\Denguekay\data\bronze\socio\data_socio_2017_2025.xlsx
# 100%|██████████| 97.6k/97.6k [00:00<00:00, 1.58MB/s]
# Descargado en: C:\Users\Rosa\RufoEsEternoElRegreso\Denguekay\data\bronze\socio\data_socio_2017_2025.xlsx
